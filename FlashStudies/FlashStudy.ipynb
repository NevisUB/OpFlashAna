# %%
# %matplotlib inline
#%pylab
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors as mpc
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

import scipy
from scipy import interpolate
import pandas as pd
import itertools
from root_numpy import root2array, root2rec, tree2rec, array2root
from ROOT import TChain

from matplotlib import rcParams
rcParams["font.size"] = "16"

# %%
def open_df(fname,treename="tree"):
    return pd.DataFrame( root2array(fname, treename) )

# %%
df = open_df('flash_study.root')

# %%
print df.columns.values
# Out:
# ['_n_flash' '_t_flash' '_pe_flash' '_q_tot' '_q_max' '_t_start' '_dt'
#  '_hit_t_v' '_hit_q_v']

# %%
plt.hist(df['_t_flash'],bins=np.linspace(0,2.0,100))
plt.show()

# %%
bins = np.linspace(0.1,20,200)
times = np.array(df['_hit_t_v'])
qhits = np.array(df['_hit_q_v'])
all_times = []
for time_arr in times:
    for t in time_arr:
        all_times.append(t)
print len(all_times)
fig = plt.figure(figsize=(8,5))
plt.hist(all_times,bins=bins,log='True')
plt.grid()
#plt.yscale(0,2000)
plt.xlabel('Time since Largest OpHit [usec]')
plt.ylabel('Number of Op Hits')
plt.title('Time-distribution of OpHits for Single muons')
plt.tick_params(axis='y',which='both',labelleft='off')
#plt.yscale('log')
plt.show()
# Out:
# 2170821

# %%
bins = np.linspace(0,3,30)
for x in xrange(10):
    times = np.array(df['_hit_t_v'][x])
    qhits = np.array(df['_hit_q_v'][x])
    #plt.scatter(times,qhits)
    print len(times)
    plt.hist(times,bins=bins)
    plt.grid()
    #plt.xlim([0,1])
    #plt.ylim([0,np.max(qhits)])
    #plt.yscale('log')
    plt.show()
# Out:
# 2153
# 2013
# 2233
# 2407
# 2145
# 2304
# 2337
# 2195
# 2162
# 2208
